# %% [markdown]
# # T6 - Ficheros

# %% [markdown]
# ---
# ## Ejercicio 1
#
# Escribe una función que reciba como parámetro el nombre de un fichero, e imprima su contenido (línea por línea), todo en mayúsculas. Luego, prueba a ejecutar esta función con el fichero `mensaje.txt`.
#
#
# Casos de prueba:
# ```
# Introduce el nombre de fichero: mensaje.txt
# THIS 1S A SECRET M3SSAGE.
# HIDE THIS MESSAGE!
#
# ```
#
# ```

# %% [markdown]
# ---
# ## Ejercicio 2
#
# Escribe un programa que lea por teclado una cadena de texto y a continuación un nombre de fichero. El programa debe añadir el texto al final del fichero, pero modificándolo previamente de la siguiente forma: cada palabra debe aparecer en una línea separada y se deben reemplazar la letra a por @, la letra e por 3 y la letra i por 1 (tanto en minúsculas como en mayúsculas).
#
#
# Casos de prueba:
# ```python
# Introduce la cadena: "clave: AeIoU1234"
# Introduce el nombre de fichero: claves.txt
# ```
# Y en el fichero `claves.txt` deben añadirse (al final) estas líneas:
# ```
# cl@v3:
# @31oU1234
#
# ```

# %% [markdown]
# ---
# ## Ejercicio 3
#
# Escribe un programa que lea el fichero `loteria.txt`, en el que hay una gran cantidad de números de 5 cifras, indicando el número ganador de la lotería diaria. Este programa debe construir e imprimir por pantalla una lista de 10 posiciones, donde cada posición de la lista representa el número de veces que la lotería ha terminado en cada número (es decir, cuántos boletos ganadores acaban en 0 aparecerá en la primera posición de la lista, cuántos en 1 en la segunda posición, etc.).
#
#
# Casos de prueba:
# ```python
# Resultado de procesar loteria.txt
#   ==> [95, 94, 110, 102, 107, 111, 106, 88, 103, 84]
# ```

# %% [markdown]
# ---
# ## Ejercicio 4
#
# Escribe un programa que lea el fichero `loteria.txt`, en el que hay una gran cantidad de números de 5 cifras, indicando el número ganador de la lotería diaria desde el 1 de enero de 2020.
#
# A partir de ese fichero debe construir otro, denominado `ganadores-diarios.csv` de tipo CSV (valores separados por comas). Cada línea del fichero CSV debe corresponder con una línea de `loteria.txt` y en esa línea, debe haber 3 valores separados por comas, en concreto:
#
# 1. La fecha del día correspondiente, en formato "AAAA-MM-DD" (cada línea es un día adicional).
# 2. El número de la lotería ganador de ese día.
# 3. La cantidad de personas que han ganado, generado como un número aleatorio entre 0 y 9.
#
# (**Nota**: puedes descartar los años bisiestos).
#
# Casos de prueba:
#
# Tras la ejecución, el contenido de `ganadores-diarios.csv` sería:
# ```python
# 61222, 2020-01-01, 4
# 20263, 2020-01-02, 5
# 63671, 2020-01-03, 2
# 29094, 2020-01-04, 7
# 59828, 2020-01-05, 0
# 64167, 2020-01-06, 0
# 90059, 2020-01-07, 3
# 21140, 2020-01-08, 9
# ...
# ```

# %% [markdown]
# ---
# ## Ejercicio 5
#
# Procesa el fichero `ganadores-diarios.csv` generado en el ejercicio anterior, y elabora un informe en el que se muestre la cantidad de días en cada mes en la serie en la que no ha habido ningún ganador. En el informe, ordena la salida por cantidad de días decreciente.
#
# Casos de prueba:
#
# El informe podría tener este aspecto:
# ```python
# Mes           Nº días sin ganador
# ======        ===================
# 2021-03       8
# 2020-06       8
# 2022-09       7
# ...
# ```
